# %%
import time, math, csv, datetime
import pandas as pd
import matplotlib.pyplot as plt
from datetime import date 
from skimpy import skim
import lightgbm as lgb
import seaborn as sns
import numpy as np

# %%
#def genderchange(df):
#    df['gender'].replace(to_replace= 'M', value = True, inplace=True )
#    df['gender'].replace(to_replace= 'F', value = False, inplace=True )

# %%
#def key_cat(df,dfref,skip=False):
  #It has a glaring issue being that the job_df resets everytime it has run and therefore when using df to convert the job values to a key it will be incorrect
#    job_dictionary = {}
#    for x, i in enumerate(df[dfref].values):
#        if i not in job_dictionary.values(): 
#            job_dictionary[x] = i
#    job_df = pandas.DataFrame.from_dict(job_dictionary, orient='index', columns=[dfref])
    #job_df
#    return(job_df[dfref])

# %%
#def key_changer(df_key, df, dfref):
#    for x in df_key:
   #     print(x)##

# %%
#def key_changer(df_key, df, dfref):
#    for x in df_key:
#        ix = df_key.index[df_key == x].tolist()
#        df[dfref].replace(to_replace = str(x), value = ix, inplace=True )

# %%
#df_train.apply(lambda x: extract_text_similarity_jaccard(x['Processed'], text), axis=1)
#genderchange(df_train)
#genderchange(df_test)
#df_job_key = key_cat(df_train,'job')
#key_changer(df_job_key, df_test,'job')

# %%
def agefromdob(df):    
    ages = []
    for x in df['dob']:
        xage = pd. to_datetime('today'). year-pd. to_datetime(x). year
        ages.append(xage)
    df['age'] = ages

# %%
df_train = pandas.read_csv('fraudtrain.csv', header=0)
df_test = pandas.read_csv('fraudtest.csv', header=0)

# %%
#df_job_key.index[df_job_key == 'Psychologist, counselling'].tolist()

# %%
skim(df_train)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                 Data Types                                                                │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                         │
# │ ┃ dataframe         ┃ Values  ┃ ┃ Column Type ┃ Count ┃                                                         │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                         │
# │ │ Number of rows    │ 1296675 │ │ string      │ 12    │                                                         │
# │ │ Number of columns │ 23      │ │ int64       │ 6     │                                                         │
# │ └───────────────────┴─────────┘ │ float64     │ 5     │                                                         │
# ...

# %%
categoricalfeatures = [ 'city', 'merchant', 'job', 'category', 'state', 'first', 'last', 'zip'] 
for x in categoricalfeatures:
    df_test[x] = pd.Categorical(df_test[x])
    df_train[x] = pd.Categorical(df_train[x])

# %%
agefromdob(df_train)
agefromdob(df_test)

# %%
features = ['lat', 'long','amt','city_pop', 'merch_lat', 'merch_long', 'unix_time', 'city', 'merchant', 'job', 'category', 'state', 'age', 'first', 'last', 'zip']
train_data = lgb.Dataset(df_train[features], df_train['is_fraud'], feature_name = 'auto')
test_data = lgb.Dataset(df_test[features] , df_test['is_fraud'], feature_name = 'auto')

# %%
params = {'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.002, 'num_leaves': 20, 'boosting': 'dart', 'max_depth': 30, 'force_col_wise': True, 'num_threads': 8, 'num_iterations': 200, 'bagging_fraction': 0.8, 'min_data_in_leaf': 15}
evals = {} #'feature_pre_filter': 'false'
model = lgb.train(params, train_data, valid_sets=[train_data, test_data], valid_names=['train', 'test'], callbacks=[lgb.record_evaluation(evals)])
# Out:
# [LightGBM] [Fatal] Cannot change feature_pre_filter after constructed Dataset handle.
# ---------------------------------------------------------------------------
# LightGBMError                             Traceback (most recent call last)
# Cell In[1321], line 3
#       1 params = {'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.002, 'num_leaves': 20, 'boosting': 'dart', 'max_depth': 30, 'force_col_wise': True, 'num_threads': 8, 'num_iterations': 200, 'bagging_fraction': 0.8, 'min_data_in_leaf': 15, 'feature_pre_filter': 'false'}
#       2 evals = {}
# ----> 3 model = lgb.train(params, train_data, valid_sets=[train_data, test_data], valid_names=['train', 'test'], callbacks=[lgb.record_evaluation(evals)])
#
# ...

# %%
lgb.plot_metric(evals)
# Out:
# <AxesSubplot: title={'center': 'Metric during training'}, xlabel='Iterations', ylabel='auc'>

# %%
pred = model.predict(
  df_test[features]
)
pred_label = np.round(pred)

# %%
np.sum(pred_label == df_test['is_fraud']) / pred_label.shape[0]
# Out:
# 0.9971964248118204

# %%
print(df_test['is_fraud'].value_counts())
# Out:
# 0    553574
# 1      2145
# Name: is_fraud, dtype: int64

# %%
print(np.sum(pred_label != df_test['is_fraud']))
# Out:
# 1558

# %%
lgb.plot_importance(model)
# Out:
# <AxesSubplot: title={'center': 'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %%
confusion = sklearn.metrics.confusion_matrix(df_test['is_fraud'], pred_label)
disp = sklearn.metrics.ConfusionMatrixDisplay(confusion)
f1score = sklearn.metrics.f1_score(df_test['is_fraud'], pred_label)
print(f1score)
disp.plot()
# Out:
# 0.5229638701775873
